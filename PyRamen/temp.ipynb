# %%
report = []
sales_item = {}
for row in csvListSales: 
    #print (row) ## 1 => id, 2 => date, 3 => creditcard, 4 => quantity, 5 => menu 
    print ()
    ## todo check if menu item exists 
    item = row[4].lstrip()
    # print (f" item is {item} and quantity is {row[3]}\n")
    #print ()
    #print ()
    sales_item = {
        item : {
            "menu-item" : item,
            "quantity" : row[3],
        }
    }
    #print (sales_item[item])
    #print()
    #print()
item = ''
quantity = 0
profit = 0
menu_item = []
# print (sales_item)
for rowMenu in csvListMenu:
    # print (row) ## 1 => item, 2 => category, 3 => description, 4 => price, 5 => cost 
    #print (row)
    item = rowMenu[0]
    price = rowMenu[-2]
    cost = rowMenu[-1]
    #print (f" Price is {price} and cost is {cost} \n")
    menu_item.append({
            "item" : item,
            "price" : price,
            "cost" : cost
    })
    #profit = cost-price
    print (f"item is {item}")
    #print ("sales_item is => ")
    #print (sales_item)
    #print ()
    #if item in sales_item.keys():
    #if sales_item.has_key(item)
    if item in sales_item:
        print (item)
        quantity = sales_item[item][quantity]
        report[item]["01-count"] += quantity
        report[item]["02-revenue"] += price * quantity
        report[item]["03-cogs"] += cost * quantity
        #report[item]["04-profit"] += profit * quantity
    else:
        print ("item is not found in sales item")
#print (report)


------------------

































































































item is house salad

item is cucumber sunomono salad

item is hiyashi wakame seaweed salad

item is agedashi tofu

item is hiyayakko tofu

item is pork floss bao

item is kakuni bao

item is edamame fried gyoza (vegan)

item is fried gyoza

item is takoyaki

item is rock shrimp tempura

item is soft-shell crab tempura

item is ebi katsu shrimp bao

item is nagomi shoyu

item is shio ramen

item is spicy miso ramen

 item spicy miso ramen is found 
item is vegetarian spicy miso

item is miso crab ramen

item is soft-shell miso crab ramen

item is tori paitan ramen

item is tonkotsu ramen

item is burnt garlic tonkotsu ramen

item is vegetarian curry + king trumpet mushroom ramen

item is truffle butter ramen

item is green tea

item is coke

item is black sesame ice cream

item is matcha ice cream

item is mango mochi ice cream

item is strawberry mochi ice cream

item is black sesame creme brulee
