# %%
#pyRamen-main.ipynb
import pathlib 
import csv
## function to write the output to file 
def writeOutputToFile(fileName, data):
    File_object = open(fileName, "w")
    File_object.writelines(data)
    File_object.close()
    
#function to read csv and returns contents as list 
def read_csv(csvFile):
    csvList = []
    with csvFile.open() as f:
        csvReader = csv.reader(f, delimiter=',', quotechar='"')
        counter = 0
        for row in csvReader:
            if (counter==0):
                next(csvReader)
            csvList = list(csvReader)
    return csvList

csvFileMenu = pathlib.Path('./menu_data.csv')
csvListMenu = read_csv(csvFileMenu)

csvFileSales = pathlib.Path('./sales_data.csv') 
csvListSales = read_csv(csvFileSales)

report = {}
sales_item = {}
counter=0
for row in csvListSales: 
    counter += counter
    #print (row) ## 1 => id, 2 => date, 3 => creditcard, 4 => quantity, 5 => menu 
    print ()
    item = row[4].lstrip()
    quantity = int(row[3])
    if item in sales_item:
        quantity += int(sales_item[item]["quantity"])
    sales_item[item] = {
        "menu-item" : item,
        "quantity" : quantity,
    }    
item = ''
quantity = 0
profit = 1
menu_item = []
counter = 0
for rowMenu in csvListMenu:
    #print (rowMenu) ## 1 => item, 2 => category, 3 => description, 4 => price, 5 => cost 
    item = rowMenu[0]
    price = rowMenu[-2]
    cost = rowMenu[-1]
    menu_item.append({
        "item" : item,
        "price" : price,
        "cost" : cost
    })
    profit = int(float(price))-int(float(cost))
    if item in sales_item:
        quantity = int(sales_item[item]['quantity'])
        revenue = int(price) * (quantity)
        cogs = int(cost) * (quantity)
        profit = profit * quantity
        if item in report:
            quantity += report[item]["01-count"]
            revenue += report[item]["02-revenue"]
            cogs += report[item]["03-cogs"]
            profit += report[item]["04-profit"]
        report[item]={
            "01-count" : quantity,
            "02-revenue" : revenue,
            "03-cogs" :  cogs,
            "04-profit" : float(profit)
          }   
    else:
        print()
        print (f"sales item does not equal {item} - NO MATCH")
print (report)
# Out:
# sales item does not equal house salad - NO MATCH
#
# sales item does not equal cucumber sunomono salad - NO MATCH
#
# sales item does not equal hiyashi wakame seaweed salad - NO MATCH
#
# sales item does not equal agedashi tofu - NO MATCH
#
# sales item does not equal hiyayakko tofu - NO MATCH
#
# sales item does not equal pork floss bao - NO MATCH
#
# sales item does not equal kakuni bao - NO MATCH
#
# sales item does not equal edamame fried gyoza (vegan) - NO MATCH
#
# sales item does not equal fried gyoza - NO MATCH
#
# sales item does not equal takoyaki - NO MATCH
#
# sales item does not equal rock shrimp tempura - NO MATCH
#
# sales item does not equal soft-shell crab tempura - NO MATCH
#
# sales item does not equal ebi katsu shrimp bao - NO MATCH
#
# sales item does not equal green tea - NO MATCH
#
# sales item does not equal coke - NO MATCH
#
# sales item does not equal black sesame ice cream - NO MATCH
#
# sales item does not equal matcha ice cream - NO MATCH
#
# sales item does not equal mango mochi ice cream - NO MATCH
#
# sales item does not equal strawberry mochi ice cream - NO MATCH
#
# sales item does not equal black sesame creme brulee - NO MATCH
# {'nagomi shoyu': {'01-count': 9132, '02-revenue': 100452, '03-cogs': 45660, '04-profit': 54792.0}, 'shio ramen': {'01-count': 9180, '02-revenue': 100980, '03-cogs': 45900, '04-profit': 55080.0}, 'spicy miso ramen': {'01-count': 9237, '02-revenue': 110844, '03-cogs': 46185, '04-profit': 64659.0}, 'vegetarian spicy miso': {'01-count': 9216, '02-revenue': 110592, '03-cogs': 46080, '04-profit': 64512.0}, 'miso crab ramen': {'01-count': 8890, '02-revenue': 106680, '03-cogs': 53340, '04-profit': 53340.0}, 'soft-shell miso crab ramen': {'01-count': 9130, '02-revenue': 127820, '03-cogs': 63910, '04-profit': 63910.0}, 'tori paitan ramen': {'01-count': 9156, '02-revenue': 119028, '03-cogs': 54936, '04-profit': 64092.0}, 'tonkotsu ramen': {'01-count': 9288, '02-revenue': 120744, '03-cogs': 55728, '04-profit': 65016.0}, 'burnt garlic tonkotsu ramen': {'01-count': 9070, '02-revenue': 126980, '03-cogs': 54420, '04-profit': 72560.0}, 'vegetarian curry + king trumpet mushroom ramen': {'01-count': 8824, '02-revenue': 114712, '03-cogs': 61768, '04-profit': 52944.0}, 'truffle butter ramen': {'01-count': 8982, '02-revenue': 125748, '03-cogs': 62874, '04-profit': 62874.0}}
